# %% [markdown]
# # **Lane Detection using OpenCV**

# %% [markdown]
# ### **0. Do the necessary imports**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### **1 a) Read the image**

# %%
img = cv2.imread("images/test.png")

# %% [markdown]
# ### **1 b) Make a copy of the original image**

# %%
lane_img = np.copy(img)

# %% [markdown]
# ### **2. Convert the image to a grayscale image**

# %%
gray = cv2.cvtColor(lane_img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(gray)
plt.show()

# %% [markdown]
# ### **3. Apply Gaussian Filtering to smoothen out the image and reduce noise**

# %%
g_blur = cv2.GaussianBlur(gray, (5,5), 0)
cv2.imshow("Gaussian Blur", g_blur)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(g_blur)
plt.show()

# %% [markdown]
# ### **4. Apply the canny method to detect the edges in the image**

# %%
canny = cv2.Canny(g_blur, 50, 150)
cv2.imshow("Canny Edge Detection", canny)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(canny)
plt.show()

# %% [markdown]
# ### **5. Specify the Region on Interest (ROI)**
#
# #### **a) Create a Triangle Shaped Polygon**

# %%
height = canny.shape[0]
polygons = np.array([
    [(200, height), (1100, height), (550, 250)]
])

# %% [markdown]
# #### **b) Create a black background with same dimension as the original image**

# %%
mask = np.zeros_like(canny)

# %% [markdown]
# #### **c) Use the fillPoly method to create a mask with the enclosed polygon**

# %%
cv2.fillPoly(mask, polygons, (255,255,255))
plt.imshow(mask)
plt.show()
cv2.imshow("Mask", mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### **6. Use the Bitwise_and operation to mask the canny image and get only the lanes**

# %%
cropped_img = cv2.bitwise_and(canny, mask)
plt.imshow(cropped_img)
plt.show()
cv2.imshow("Masked Canny Image", cropped_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### **7. Perform Hough Transformation to draw lines on the cropped image**

# %%
line_image = np.zeros_like(lane_img)
line = cv2.HoughLinesP(cropped_img, 2, np.pi/180, 100, np.array([]), minLineLength=40, maxLineGap=5)
if line is not None:
    for i in line:
        x1, y1, x2, y2 = i.reshape(4)
        cv2.line(line_image, (x1,y1), (x2, y2), (255, 0,0), 10)

cv2.imshow("Line Image", line_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(line_image)
plt.show()

# %% [markdown]
# ### **8. Superpose the line image and the lane image to get the final result**

# %%
final_image = cv2.addWeighted(lane_img, 0.8, line_image, 1, 1)
cv2.imshow("Final Image", final_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(final_image)
plt.show()
